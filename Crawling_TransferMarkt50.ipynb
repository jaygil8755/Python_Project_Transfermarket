# %% [markdown]
# ### Transfermarkt 크롤링
# - 첫페이지와 두번째 페이지 50명 정보

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
import time

# requsts.get()으로 url정보 요청하기 
headers = {'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 \
(KHTML, like Gecko) Chrome/87.0.4280.88 Safari/537.36'}

number=[]
name=[]
position=[]
age=[]
nation=[]
team=[]
value=[]

# 두번째 페이지까지 크롤링하기 
for i in range(1, 3):

    url = f"https://www.transfermarkt.com/spieler-statistik/wertvollstespieler/marktwertetop/plus/ajax/yw1/0//page/{i}"

    r= requests.get(url, headers=headers)
    r.status_code  #200이 나오면 정상

    soup = BeautifulSoup(r.text, 'html.parser')  # r.content 대신 r.text도 가능

    player_info= soup.find_all('tr', class_=['odd', 'even'])

    # player_info에서 'td'태그만 모두 찾기
    for info in player_info:
        player = info.find_all("td")

        number.append(player[0].text)
        name.append(player[3].text)
        position.append(player[4].text)
        age.append(player[5].text)
        nation.append(player[6].img['alt'])
        team.append(player[7].img['alt'])
        value.append(player[8].text.strip())
    
    time.sleep(1)

    # pd.DataFrame()으로 저장하기

df = pd.DataFrame(
        {"number":number,
         "name":name,
         "position":position,
         "age":age,
         "nation":nation,
         "team":team,
         "value":value}
    )
df
# Out:
#    number                     name            position age        nation  \
# 0       1            Kylian Mbappé      Centre-Forward  22        France
# 1       2                   Neymar         Left Winger  28        Brazil
# 2       3               Sadio Mané         Left Winger  28       Senegal
# 3       4            Mohamed Salah        Right Winger  28         Egypt
# 4       5               Harry Kane      Centre-Forward  27       England
# 5       6          Kevin De Bruyne  Attacking Midfield  29       Belgium
# 6       7   Trent Alexander-Arnold          Right-Back  22       England
# 7       8          Raheem Sterling         Left Winger  26       England
# 8       9               João Félix      Second Striker  21      Portugal
# 9      10           Erling Haaland      Centre-Forward  20        Norway
# 10     11             Jadon Sancho        Right Winger  20       England
# 11     12             Lionel Messi        Right Winger  33     Argentina
# 12     13          Bruno Fernandes  Attacking Midfield  26      Portugal
# 13     14             Serge Gnabry        Right Winger  25       Germany
# 14     15                Jan Oblak          Goalkeeper  27      Slovenia
# 15     16            Romelu Lukaku      Centre-Forward  27       Belgium
# 16     17            Heung-min Son         Left Winger  28  Korea, South
# 17     18           Joshua Kimmich  Defensive Midfield  25       Germany
# 18     19              Kai Havertz  Attacking Midfield  21       Germany
# 19     20                Ansu Fati         Left Winger  18         Spain
# 20     21          Alphonso Davies           Left-Back  20        Canada
# 21     22          Marcus Rashford         Left Winger  23       England
# 22     23          Virgil van Dijk         Centre-Back  29   Netherlands
# 23     24        Antoine Griezmann      Second Striker  29        France
# 24     25                  Alisson          Goalkeeper  28        Brazil
# 25     26         Matthijs de Ligt         Centre-Back  21   Netherlands
# 26     27         Andrew Robertson           Left-Back  26      Scotland
# 27     28         Thibaut Courtois          Goalkeeper  28       Belgium
# 28     29    Marc-André ter Stegen          Goalkeeper  28       Germany
# 29     30          Roberto Firmino      Centre-Forward  29        Brazil
# 30     31         Lautaro Martínez      Centre-Forward  23     Argentina
# 31     32        Federico Valverde    Central Midfield  22       Uruguay


# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
import time

# requsts.get()으로 url정보 요청하기 
headers = {'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 \
(KHTML, like Gecko) Chrome/87.0.4280.88 Safari/537.36'}

player_list=[]

for i in range(1, 3):

    url = f"https://www.transfermarkt.com/spieler-statistik/wertvollstespieler/marktwertetop/plus/ajax/yw1/0//page/{i}"

    r= requests.get(url, headers=headers)
    r.status_code  

    soup = BeautifulSoup(r.text, 'html.parser')  # r.content 대신 r.text도 가능

    player_info= soup.find_all('tr', class_=['odd', 'even'])

    # player_info에서 'td'태그만 모두 찾기
    for info in player_info:
        player = info.find_all("td")

        number = player[0].text 
        name = player[3].text 
        position = player[4].text 
        age = player[5].text 
        nation = player[6].img['alt'] 
        team = player[7].img['alt'] 
        value = player[8].text.strip()
#         value = value[1:-1]
#         print(value)
        
        player_list.append([number, name, position, age, nation, team, value])
    
    time.sleep(1)

    # pd.DataFrame()으로 저장하기

df2 = pd.DataFrame(player_list, 
                   columns=['number', 'name', 'position', 'age', 'nation', 'team', 'value'])
df2
# Out:
#    number                     name            position age        nation  \
# 0       1            Kylian Mbappé      Centre-Forward  22        France
# 1       2                   Neymar         Left Winger  28        Brazil
# 2       3               Sadio Mané         Left Winger  28       Senegal
# 3       4            Mohamed Salah        Right Winger  28         Egypt
# 4       5               Harry Kane      Centre-Forward  27       England
# 5       6          Kevin De Bruyne  Attacking Midfield  29       Belgium
# 6       7   Trent Alexander-Arnold          Right-Back  22       England
# 7       8          Raheem Sterling         Left Winger  26       England
# 8       9               João Félix      Second Striker  21      Portugal
# 9      10           Erling Haaland      Centre-Forward  20        Norway
# 10     11             Jadon Sancho        Right Winger  20       England
# 11     12             Lionel Messi        Right Winger  33     Argentina
# 12     13          Bruno Fernandes  Attacking Midfield  26      Portugal
# 13     14             Serge Gnabry        Right Winger  25       Germany
# 14     15                Jan Oblak          Goalkeeper  27      Slovenia
# 15     16            Romelu Lukaku      Centre-Forward  27       Belgium
# 16     17            Heung-min Son         Left Winger  28  Korea, South
# 17     18           Joshua Kimmich  Defensive Midfield  25       Germany
# 18     19              Kai Havertz  Attacking Midfield  21       Germany
# 19     20                Ansu Fati         Left Winger  18         Spain
# 20     21          Alphonso Davies           Left-Back  20        Canada
# 21     22          Marcus Rashford         Left Winger  23       England
# 22     23          Virgil van Dijk         Centre-Back  29   Netherlands
# 23     24        Antoine Griezmann      Second Striker  29        France
# 24     25                  Alisson          Goalkeeper  28        Brazil
# 25     26         Matthijs de Ligt         Centre-Back  21   Netherlands
# 26     27         Andrew Robertson           Left-Back  26      Scotland
# 27     28         Thibaut Courtois          Goalkeeper  28       Belgium
# 28     29    Marc-André ter Stegen          Goalkeeper  28       Germany
# 29     30          Roberto Firmino      Centre-Forward  29        Brazil
# 30     31         Lautaro Martínez      Centre-Forward  23     Argentina
# 31     32        Federico Valverde    Central Midfield  22       Uruguay
